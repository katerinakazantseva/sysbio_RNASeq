# %% [markdown]
# <a href="https://colab.research.google.com/github/katerinakazantseva/sysbio/blob/main/cnvtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from plotnine.data import economics
from plotnine.data import economics
from plotnine import ggplot, aes, geom_line, geom_point

ggplot(economics)+aes(x="date", y="pop")+geom_point()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8738536979513)>

# %%
import os
#import zip

#stream = os.popen('samtools dept toy.sam -a > output.txt')
#stream2=os.popen('samtools depth toy2.sam -a > output2.txt')
#output = stream.read()
#output2=stream2.read()
file1=open('output.txt','r')
file2=open('output2.txt','r')


for lineA, lineB in zip(file1, file2):
#for line in file1.readlines():
  #print(int(lineA.split('      ')[-1])-int(lineB.split('   ')[-1]))
   print(int(lineA.split('      ')[-1][0])-int(lineB.split('    ')[-1][0]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-bdcd65326ed3> in <module>()
#       6 #output = stream.read()
#       7 #output2=stream2.read()
# ----> 8 file1=open('output.txt','r')
#       9 file2=open('output2.txt','r')
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output.txt'
